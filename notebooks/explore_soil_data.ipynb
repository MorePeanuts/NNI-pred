# %%
from nni_pred.data import SoilTabularDataset

# %%
data = SoilTabularDataset()

# %%
X, y_dict, groups = data.prepare_data()
X
# Out:
#       Season     pH        TN       TOC  Temp   Rain       EVI    FCOVER  LAI  \
# ID
# SS01   Rainy  6.150  0.212657  2.075193  28.6   69.7  0.542248  0.055793  1.8
# SS02   Rainy  6.265  0.085112  0.790420  28.6   69.7  0.308404  0.000000  1.1
# SS03   Rainy  6.130  0.113238  1.085111  28.8  116.8  0.612967  0.186347  1.8
# SS04   Rainy  6.300  0.065465  0.524514  28.8  115.2  0.425735  0.000000  2.0
# SS05   Rainy  6.345  0.187590  1.564037  28.8  115.2  0.530465  0.164292  1.3
# ...      ...    ...       ...       ...   ...    ...       ...       ...  ...
# NS58  Normal  6.630  0.059072  0.575940  20.3    0.0  0.511269  0.738688  1.0
# NS59  Normal  6.855  0.030762  0.273771  18.8   32.0  0.336794  0.488164  0.9
# NS60  Normal  6.635  0.216329  1.973027  18.8   32.0  0.444529  0.584908  1.1
# NS61  Normal  6.905  0.111991  0.877793  20.3    0.0  0.541255  0.706015  0.8
# NS62  Normal  7.000  0.064989  0.623280  20.3    0.0  0.318995  0.535108  0.9
#
# ...

# %%
y_dict
# Out:
# {'THIA': ID
#  SS01     3.170000
#  SS02     0.590000
#  SS03     3.840000
#  SS04     5.080000
#  SS05     1.010000
#            ...
#  NS58     0.110000
#  NS59     5.610000
#  NS60    49.580000
#  NS61     0.000707
#  NS62     0.000707
#  Name: THIA, Length: 186, dtype: float64,
#  'IMI': ID
#  SS01     5.27
#  SS02     0.78
#  SS03    11.26
#  SS04    17.82
#  SS05     2.91
#          ...
#  NS58     0.22
#  NS59     2.49
#  NS60     8.18
#  NS61     6.19
#  NS62     0.23
#  Name: IMI, Length: 186, dtype: float64,
#  'CLO': ID
#  SS01     4.230000
#  SS02     1.380000
#  SS03     2.490000
#  SS04    12.390000
#  SS05     4.630000
#            ...
#  NS58     0.120000
#  NS59    10.120000
#  NS60    23.810000
#  NS61     0.290000
#  NS62     0.001061
#  Name: CLO, Length: 186, dtype: float64,
#  'parentNNIs': ID
#  SS01    12.67
#  SS02     2.77
#  SS03    17.59
#  SS04    35.29
#  SS05     8.55
#          ...
#  NS58     0.45
#  NS59    18.34
#  NS60    81.57
#  NS61     6.65
# ...
